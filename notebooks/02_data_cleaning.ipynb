# %%
import pandas as pd
import numpy as np

pd.set_option("display.max_columns", None)

df = pd.read_csv("../data/raw/lending_club_loan_two.csv")

df.shape
# Out:
# (396030, 27)

# %%
df = df[df["loan_status"].isin(["Fully Paid", "Charged Off"])]

df["default_flag"] = df["loan_status"].apply(
    lambda x: 1 if x == "Charged Off" else 0
)

df["default_flag"].value_counts(normalize=True)
# Out:
# default_flag
# 0    0.803871
# 1    0.196129
# Name: proportion, dtype: float64

# %%
drop_cols = [
    "grade", # internal scoring
    "sub_grade", # internal scoring
    "emp_title", # high cardinality
    "title", # redundant
    "address", # unused now
    "loan_status", # because we have default_flag
    "application_type" # because we only have one type
]

df = df.drop(columns=drop_cols)

df.shape
# Out:
# (396030, 21)

# %%
df["term"] = df["term"].str.extract(r"(\d+)").astype(int)

# %%
df["emp_length"] = df["emp_length"].str.replace("years", "", regex=False)
df["emp_length"] = df["emp_length"].str.replace("year", "", regex=False)
df["emp_length"] = df["emp_length"].str.replace("+", "", regex=False)
df["emp_length"] = df["emp_length"].str.replace("< 1", "0.5", regex=False)
df["emp_length"] = df["emp_length"].str.strip()
df["emp_length"] = pd.to_numeric(df["emp_length"], errors="coerce")

# %%
df["issue_d"] = pd.to_datetime(df["issue_d"], format="%b-%Y")
df["issue_year"] = df["issue_d"].dt.year

# %%
df["earliest_cr_line"] = pd.to_datetime(df["earliest_cr_line"], format="%b-%Y")

df["credit_history_years"] = (
    df["issue_d"].dt.year - df["earliest_cr_line"].dt.year
)

# %%
df = df.drop(columns=["issue_d", "earliest_cr_line"])

# %%
df["mort_acc"] = df["mort_acc"].fillna(df["mort_acc"].median())

# %%
df["emp_length"] = df["emp_length"].fillna(df["emp_length"].median())

# %%
if df["revol_util"].dtype == "object":
    df["revol_util"] = df["revol_util"].str.replace("%", "")
    df["revol_util"] = pd.to_numeric(df["revol_util"], errors="coerce")

df["revol_util"] = df["revol_util"].fillna(df["revol_util"].median())

# %%
df = pd.get_dummies(df, drop_first=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 396030 entries, 0 to 396029
# Data columns (total 38 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   loan_amnt                            396030 non-null  float64
#  1   term                                 396030 non-null  int32
#  2   int_rate                             396030 non-null  float64
#  3   installment                          396030 non-null  float64
#  4   emp_length                           396030 non-null  float64
#  5   annual_inc                           396030 non-null  float64
#  6   dti                                  396030 non-null  float64
#  7   open_acc                             396030 non-null  float64
#  8   pub_rec                              396030 non-null  float64
#  9   revol_bal                            396030 non-null  float64
#  10  revol_util                           396030 non-null  float64
#  11  total_acc                            396030 non-null  float64
#  12  mort_acc                             396030 non-null  float64
#  13  pub_rec_bankruptcies                 395495 non-null  float64
#  14  default_flag                         396030 non-null  int64
#  15  issue_year                           396030 non-null  int32
#  16  credit_history_years                 396030 non-null  int32
#  17  home_ownership_MORTGAGE              396030 non-null  bool
#  18  home_ownership_NONE                  396030 non-null  bool
#  19  home_ownership_OTHER                 396030 non-null  bool
#  20  home_ownership_OWN                   396030 non-null  bool
#  21  home_ownership_RENT                  396030 non-null  bool
#  22  verification_status_Source Verified  396030 non-null  bool
#  23  verification_status_Verified         396030 non-null  bool
#  24  purpose_credit_card                  396030 non-null  bool
#  25  purpose_debt_consolidation           396030 non-null  bool
#  26  purpose_educational                  396030 non-null  bool
#  27  purpose_home_improvement             396030 non-null  bool
#  28  purpose_house                        396030 non-null  bool
#  29  purpose_major_purchase               396030 non-null  bool
#  30  purpose_medical                      396030 non-null  bool
#  31  purpose_moving                       396030 non-null  bool
#  32  purpose_other                        396030 non-null  bool
#  33  purpose_renewable_energy             396030 non-null  bool
#  34  purpose_small_business               396030 non-null  bool
#  35  purpose_vacation                     396030 non-null  bool
#  36  purpose_wedding                      396030 non-null  bool
#  37  initial_list_status_w                396030 non-null  bool
# dtypes: bool(21), float64(13), int32(3), int64(1)
# memory usage: 54.8 MB

# %%
df.isnull().sum().sum()
# Out:
# 535

# %%
# The missing values is 535, and pub_rec_bankruptcies collum has 395495 values, 
# so the missing values is only 0.1% of the total values, 
# we can fill it with 0 because it means no public record of bankruptcies.
df["pub_rec_bankruptcies"] = df["pub_rec_bankruptcies"].fillna(0)

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
print(df.dtypes.to_string())
# Out:
# loan_amnt                              float64
# term                                     int32
# int_rate                               float64
# installment                            float64
# emp_length                             float64
# annual_inc                             float64
# dti                                    float64
# open_acc                               float64
# pub_rec                                float64
# revol_bal                              float64
# revol_util                             float64
# total_acc                              float64
# mort_acc                               float64
# pub_rec_bankruptcies                   float64
# default_flag                             int64
# issue_year                               int32
# credit_history_years                     int32
# home_ownership_MORTGAGE                   bool
# home_ownership_NONE                       bool
# home_ownership_OTHER                      bool
# home_ownership_OWN                        bool
# home_ownership_RENT                       bool
# verification_status_Source Verified       bool
# verification_status_Verified              bool
# purpose_credit_card                       bool
# purpose_debt_consolidation                bool
# purpose_educational                       bool
# purpose_home_improvement                  bool
# purpose_house                             bool
# purpose_major_purchase                    bool
# purpose_medical                           bool
# purpose_moving                            bool
# purpose_other                             bool
# purpose_renewable_energy                  bool
# purpose_small_business                    bool
# purpose_vacation                          bool
# purpose_wedding                           bool
# initial_list_status_w                     bool

# %%
df.to_csv("../data/processed/lending_club_clean.csv", index=False)
